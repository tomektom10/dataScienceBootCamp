# %% [markdown]
# <a href="https://colab.research.google.com/github/tomektom10/dataScienceBootCamp/blob/main/moje_projekt_cukier.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_excel("Cukry_wszystkie.xlsx")
df
df.columns
import numpy as np

# %%
df1 = df[["SBES1H23", "Unnamed: 1"]].iloc[1:]
df1
# Out:
#                  SBES1H23 Unnamed: 1
# 1     2023-02-28 00:00:00       2.01
# 2     2023-02-27 00:00:00       1.82
# 3     2023-02-24 00:00:00       1.62
# 4     2023-02-23 00:00:00       1.27
# 5     2023-02-22 00:00:00       1.39
# ...                   ...        ...
# 3033  2012-12-26 00:00:00        0.1
# 3034  2012-12-24 00:00:00       0.12
# 3035  2012-12-21 00:00:00        0.1
# 3036  2012-12-20 00:00:00       0.11
# 3037  2012-12-19 00:00:00       0.11
#
# [3037 rows x 2 columns]

# %%
# przerobiłem tak zeby w przypadku braku danych wyswietlało puste.

# %%
for year in range(2014, 2024):  # Zakres lat od 2014 do 2023
    specyfic_date = str(year) + "-" + day_month
    try:
        specyfic_date = datetime.datetime.strptime(specyfic_date, '%Y-%m-%d')

        df_row1 = df1[df1["SBES1H23"] == specyfic_date]
        df_row2 = df2[df2["SBES1K23"] == specyfic_date]

        if not df_row1.empty and not df_row2.empty:
            cena_flaja = []
            for i, value in enumerate(df_row1['Unnamed: 1'].values):
                if i < len(df_row2["Unnamed: 4"].values):
                    roznica = value - df_row2["Unnamed: 4"].values[i]
                    cena_flaja.append(roznica)

            if len(cena_flaja) == 1:
                wynik_dict["Date"].append(specyfic_date)
                wynik_dict["cena_flaja1"].append(cena_flaja[0])
                wynik_dict["cena_flaja2"].append(np.nan)
            elif len(cena_flaja) == 2:
                wynik_dict["Date"].append(specyfic_date)
                wynik_dict["cena_flaja1"].append(cena_flaja[0])
                wynik_dict["cena_flaja2"].append(cena_flaja[1])
            else:
                wynik_dict["Date"].append(specyfic_date)
                wynik_dict["cena_flaja1"].append(np.nan)
                wynik_dict["cena_flaja2"].append(np.nan)
        else:
            wynik_dict["Date"].append(specyfic_date)
            wynik_dict["cena_flaja1"].append(np.nan)
            wynik_dict["cena_flaja2"].append(np.nan)
    except ValueError:
        wynik_dict["Date"].append(specyfic_date)
        wynik_dict["cena_flaja1"].append(np.nan)
        wynik_dict["cena_flaja2"].append(np.nan)

df_wynik = pd.DataFrame(wynik_dict)

# %%
# Out:
#         Date  cena_flaja1  cena_flaja2
# 0 2014-02-24         0.05        -0.15
# 1 2015-02-24        -0.09         0.31
# 2 2016-02-24         0.00        -0.05
# 3 2017-02-24         0.04        -0.25
# 4 2018-02-24          NaN          NaN
# 5 2019-02-24          NaN          NaN
# 6 2020-02-24         0.07         0.42
# 7 2021-02-24         0.27         0.29
# 8 2022-02-24         0.22         0.24
# 9 2023-02-24         1.17          NaN

# %%
def oblicz_ceny_flaja(df1, df2, kod1, kod2, cena1, cena2):
  day_month = "02-24"
  wynik_dict = {"Date":[], "cena_flaja1":[], "cena_flaja2": []}
  for year in [2023, 2022, 2021, 2020]:
    specyfic_date = str(year) + "-" + day_month
    specyfic_date = datetime.datetime.strptime(specyfic_date, '%Y-%m-%d')
    print(specyfic_date)
    df_row1 = df1[df1[kod1] == specyfic_date]
    print(df_row1)

    df_row2 = df2[df2[kod2] == specyfic_date]
    print(df_row2)
    cena_flaja = []
    for i, value in enumerate(df_row1[cena1].values):
      roznica = value - df_row2[cena2].values[i]
      cena_flaja.append(roznica)
    if len(cena_flaja) == 1:
      wynik_dict["Date"].append(specyfic_date)
      wynik_dict["cena_flaja1"].append(cena_flaja[0])
      wynik_dict["cena_flaja2"].append(np.nan)
    else:
      wynik_dict["Date"].append(specyfic_date)
      wynik_dict["cena_flaja1"].append(cena_flaja[0])
      wynik_dict["cena_flaja2"].append(cena_flaja[1])
  df_wynik = pd.DataFrame(wynik_dict)
  return df_wynik

# %%
df_wynik = oblicz_ceny_flaja(df1, df2, "SBES1H23", "SBES1K23", "Unnamed: 1", "Unnamed: 4")
# Out:
# 2023-02-24 00:00:00
#               SBES1H23 Unnamed: 1
# 3  2023-02-24 00:00:00       1.62
#                SBES1K23 Unnamed: 4
# 45  2023-02-24 00:00:00       0.45
# 2022-02-24 00:00:00
#                 SBES1H23 Unnamed: 1
# 254  2022-02-24 00:00:00       0.67
# 307  2022-02-24 00:00:00       0.39
#                 SBES1K23 Unnamed: 4
# 296  2022-02-24 00:00:00       0.45
# 350  2022-02-24 00:00:00       0.15
# 2021-02-24 00:00:00
#                 SBES1H23 Unnamed: 1
# 560  2021-02-24 00:00:00       0.99
# 611  2021-02-24 00:00:00          1
#                 SBES1K23 Unnamed: 4
# 603  2021-02-24 00:00:00       0.72
# 655  2021-02-24 00:00:00       0.71
# 2020-02-24 00:00:00
#                 SBES1H23 Unnamed: 1
# 864  2020-02-24 00:00:00        0.5
# 917  2020-02-24 00:00:00       0.56
#                 SBES1K23 Unnamed: 4
# 908  2020-02-24 00:00:00       0.43
# 960  2020-02-24 00:00:00       0.14

# %%
df_wynik
# Out:
#         Date  cena_flaja1  cena_flaja2
# 0 2023-02-24         1.17          NaN
# 1 2022-02-24         0.22         0.24
# 2 2021-02-24         0.27         0.29
# 3 2020-02-24         0.07         0.42
