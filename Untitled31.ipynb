# %% [markdown]
# <a href="https://colab.research.google.com/github/tomektom10/dataScienceBootCamp/blob/main/Untitled31.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import pandas as pd
# !pip install energyquantified

# %%
import energyquantified
from energyquantified.metadata import Aggregation
print(dir(Aggregation))
# Out:
# ['AVERAGE', 'MAX', 'MEAN', 'MIN', 'SUM', '__class__', '__doc__', '__members__', '__module__']

# %%
# !pip install energyquantified

# %%
from energyquantified import EnergyQuantified
from energyquantified.time import Frequency
from energyquantified.metadata import Aggregation


eq = EnergyQuantified(api_key='c8a40894-1e7b0499-0d17a72a-b985f4c4')

timeseries = eq.timeseries.load(
   'SK Consumption Index Cooling % 15min Synthetic',
   begin=date(2024, 8, 1),
   end=date(2024, 9, 18),
   frequency=Frequency.P1D,
   aggregation=Aggregation.MEAN,
   threshold=0
)

# %%
timeseries
# Out:
# <Timeseries: resolution="<Resolution: frequency=P1D, timezone=CET>", curve="SK Consumption Index Cooling % 15min Synthetic", unit="%", begin="2024-08-01 00:00:00+02:00", end="2024-09-12 00:00:00+02:00">

# %%
df = pd.DataFrame(timeseries)

# Wyświetlanie DataFrame
df
# Out:
#                         date  value
# 0  2024-08-01 00:00:00+02:00  38.55
# 1  2024-08-02 00:00:00+02:00  28.07
# 2  2024-08-03 00:00:00+02:00  11.66
# 3  2024-08-04 00:00:00+02:00  11.38
# 4  2024-08-05 00:00:00+02:00   2.60
# 5  2024-08-06 00:00:00+02:00  11.75
# 6  2024-08-07 00:00:00+02:00  27.96
# 7  2024-08-08 00:00:00+02:00  27.13
# 8  2024-08-09 00:00:00+02:00  25.95
# 9  2024-08-10 00:00:00+02:00  40.57
# 10 2024-08-11 00:00:00+02:00  50.51
# 11 2024-08-12 00:00:00+02:00  49.15
# 12 2024-08-13 00:00:00+02:00  53.54
# 13 2024-08-14 00:00:00+02:00  55.43
# 14 2024-08-15 00:00:00+02:00  57.25
# 15 2024-08-16 00:00:00+02:00  58.14
# 16 2024-08-17 00:00:00+02:00  52.34
# 17 2024-08-18 00:00:00+02:00  37.65
# 18 2024-08-19 00:00:00+02:00  39.56
# 19 2024-08-20 00:00:00+02:00  36.72
# 20 2024-08-21 00:00:00+02:00  31.80
# 21 2024-08-22 00:00:00+02:00   6.92
# 22 2024-08-23 00:00:00+02:00  29.98
# 23 2024-08-24 00:00:00+02:00  48.13
# 24 2024-08-25 00:00:00+02:00  52.84
# ...

# %%
df.columns
# Out:
# Index(['date', 'value'], dtype='object')

# %%
pip install pandas openpyxl

# %%
df['date'] = pd.to_datetime(df['date']).dt.tz_localize(None)

# Formatowanie kolumny 'date' na 'dzień-miesiąc-rok'
df['date'] = df['date'].dt.strftime('%d-%m-%Y')
df.to_excel('dane.xlsx', index=False, engine='openpyxl')

# %%
df.to_excel('dane.xlsx', index=False, engine='openpyxl')

# %%
df
# Out:
#           date  value
# 0   01-08-2024  38.55
# 1   02-08-2024  28.07
# 2   03-08-2024  11.66
# 3   04-08-2024  11.38
# 4   05-08-2024   2.60
# 5   06-08-2024  11.75
# 6   07-08-2024  27.96
# 7   08-08-2024  27.13
# 8   09-08-2024  25.95
# 9   10-08-2024  40.57
# 10  11-08-2024  50.51
# 11  12-08-2024  49.15
# 12  13-08-2024  53.54
# 13  14-08-2024  55.43
# 14  15-08-2024  57.25
# 15  16-08-2024  58.14
# 16  17-08-2024  52.34
# 17  18-08-2024  37.65
# 18  19-08-2024  39.56
# 19  20-08-2024  36.72
# 20  21-08-2024  31.80
# 21  22-08-2024   6.92
# 22  23-08-2024  29.98
# 23  24-08-2024  48.13
# 24  25-08-2024  52.84
# 25  26-08-2024  34.15
# 26  27-08-2024  37.66
# 27  28-08-2024  49.09
# 28  29-08-2024  51.47
# 29  30-08-2024  51.27
# 30  31-08-2024  54.53
# 31  01-09-2024  42.21
# 32  02-09-2024  45.31
# 33  03-09-2024  47.41
# 34  04-09-2024  45.14
# 35  05-09-2024  36.67
# 36  06-09-2024  29.79
# 37  07-09-2024  36.55
# 38  08-09-2024  42.57
# 39  09-09-2024   4.01
# ...
