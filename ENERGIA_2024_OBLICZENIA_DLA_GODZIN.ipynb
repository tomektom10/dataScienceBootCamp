# %% [markdown]
# <a href="https://colab.research.google.com/github/tomektom10/dataScienceBootCamp/blob/main/ENERGIA_2024_OBLICZENIA_DLA_GODZIN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import pandas as pd
import numpy as np

# %%
df = pd.read_excel("Total_results_statystyka_024-01-01_2024-01-23.xlsx")

# %%
df.columns
# Out:
# Index(['Delivery day', 'Period', 'DA price', 'Bilans', 'Price Average ',
#        'Weighted average price ', 'Minimal price', 'Maximal price ',
#        'Last price '],
#       dtype='object')

# %%
# Dodanie kolumny 'Profit/Loss', która oblicza zysk lub stratę na podstawie 'DA price' i 'Bilans'
df['Profit_Loss'] = df['Bilans'] - df['DA price']
df  # Wyświetlenie pierwszych kilku wierszy zaktualizowanego DataFrame
# Out:
#     Delivery day  Period  DA price    Bilans  Price Average   \
# 0     2024-01-01       1      0.10   -5.0000            3.14
# 1     2024-01-01       2      0.01   29.2500            3.75
# 2     2024-01-01       3      0.05   -5.0000            4.21
# 3     2024-01-01       4      0.01   -5.0000            4.15
# 4     2024-01-01       5      0.01   -4.4975            3.73
# ..           ...     ...       ...       ...             ...
# 547   2024-01-23      20     99.78  137.1900          112.37
# 548   2024-01-23      21     95.43   65.1750           90.82
# 549   2024-01-23      22     82.13   92.9750           81.45
# 550   2024-01-23      23     73.50   97.7500           82.49
# 551   2024-01-23      24     50.13   97.7500           61.41
#
#      Weighted average price   Minimal price  Maximal price   Last price   \
# 0                       4.09           0.80            5.00         4.50
# 1                       6.11          -2.51           20.18         2.18
# 2                       7.00          -1.28           26.12         2.11
# 3                       2.13          -0.50            7.21         4.59
# 4                       2.89          -0.50            8.49         6.01
# ..                       ...            ...             ...          ...
# 547                   116.05          93.10          130.60       130.60
# 548                    98.89          81.51          125.85        84.00
# 549                    86.23          70.00          107.29        76.00
# 550                    85.01          73.50           95.48        73.50
# 551                    59.24          56.00           69.90        69.90
#
#      Profit_Loss
# 0        -5.1000
# 1        29.2400
# 2        -5.0500
# 3        -5.0100
# 4        -4.5075
# ..           ...
# 547      37.4100
# 548     -30.2550
# 549      10.8450
# 550      24.2500
# 551      47.6200
#
# [552 rows x 10 columns]

# %%
# Grupowanie danych wg 'Period' i obliczanie średniej, min, max dla 'DA price'
grouped = df.groupby('Period')['DA price'].agg(['mean', 'min', 'max'])

print(grouped)

# WARTOSCI DLA GODZIN Z ROKU 2024
# Out:
#               mean    min     max
# Period
# 1        69.163478   0.10   91.75
# 2        65.901739   0.01   88.59
# 3        63.805652   0.05   87.25
# 4        60.429130   0.01   85.86
# 5        61.465217   0.01   88.47
# 6        68.241304   0.01   95.18
# 7        81.709565   0.04  111.24
# 8        93.431739   0.01  129.67
# 9       100.577826   0.00  144.11
# 10       96.723913   0.04  138.60
# 11       90.863043   0.06  122.01
# 12       86.987391   0.54  116.09
# 13       82.920435   2.24  115.40
# 14       83.813478   3.44  118.35
# 15       88.966087  11.18  122.06
# 16       97.063043  43.85  134.79
# 17      107.084783  55.61  143.59
# 18      110.689130  63.03  147.93
# 19      108.420870  61.39  140.00
# 20      104.658261  54.94  132.31
# 21       97.646522  48.40  125.75
# 22       86.694783  40.46  112.36
# 23       82.826957  40.93  105.68
# 24       74.345217  25.28   96.69

# %%
# Grupowanie danych wg 'Period' i obliczanie średniej, min, max dla 'DA price' oraz sumy dla 'Bilans'
grouped1 = df.groupby('Period').agg({'DA price': ['mean', 'min', 'max'], 'Bilans': 'mean'})

print(grouped1)

# DOŁOŻYŁEM JESZCZE  BILANS SREDNIA ZE WSZYSTKICH DNI
# Out:
#           DA price                    Bilans
#               mean    min     max       mean
# Period
# 1        69.163478   0.10   91.75  43.104891
# 2        65.901739   0.01   88.59  48.682826
# 3        63.805652   0.05   87.25  45.861630
# 4        60.429130   0.01   85.86  53.102707
# 5        61.465217   0.01   88.47  51.568783
# 6        68.241304   0.01   95.18  59.139130
# 7        81.709565   0.04  111.24  71.573478
# 8        93.431739   0.01  129.67  73.543293
# 9       100.577826   0.00  144.11  71.099076
# 10       96.723913   0.04  138.60  75.147000
# 11       90.863043   0.06  122.01  54.985000
# 12       86.987391   0.54  116.09  81.191891
# 13       82.920435   2.24  115.40  75.900457
# 14       83.813478   3.44  118.35  70.378370
# 15       88.966087  11.18  122.06  80.128489
# 16       97.063043  43.85  134.79  75.068793
# 17      107.084783  55.61  143.59  84.329641
# 18      110.689130  63.03  147.93  87.364663
# 19      108.420870  61.39  140.00  81.489783
# 20      104.658261  54.94  132.31  86.291304
# 21       97.646522  48.40  125.75  74.617554
# 22       86.694783  40.46  112.36  71.550370
# 23       82.826957  40.93  105.68  76.587457
# 24       74.345217  25.28   96.69  68.293348

# %%
# Obliczenie łącznego wyniku dla 'Profit/Loss' dla poszczególnych okresów z kolumny 'Period'
total_profit_loss_by_period = df.groupby('Period')['Profit_Loss'].sum()

total_profit_loss_by_period.head  # Wyświetlenie pierwszych kilku wyników
# ZYSKI/STRATY ŁĄCZNIE DLA POSZCZEGULNYCH GODZIN
# Out:
# <bound method NDFrame.head of Period
# 1    -599.34750
# 2    -396.03500
# 3    -412.71250
# 4    -168.50775
# 5    -227.61800
# 6    -209.35000
# 7    -233.13000
# 8    -457.43425
# 9    -678.01125
# 10   -496.26900
# 11   -825.19500
# 12   -133.29650
# 13   -161.45950
# 14   -309.00750
# 15   -203.26475
# 16   -505.86775
# 17   -523.36825
# 18   -536.46275
# 19   -619.41500
# 20   -422.44000
# 21   -529.66625
# 22   -348.32150
# 23   -143.50850
# 24   -139.19300
# Name: Profit_Loss, dtype: float64>

# %%
################    NOWE  #########

# %%
df
# Out:
#     Delivery day  Period  DA price    Bilans  Price Average   \
# 0     2024-01-01       1      0.10   -5.0000            3.14
# 1     2024-01-01       2      0.01   29.2500            3.75
# 2     2024-01-01       3      0.05   -5.0000            4.21
# 3     2024-01-01       4      0.01   -5.0000            4.15
# 4     2024-01-01       5      0.01   -4.4975            3.73
# ..           ...     ...       ...       ...             ...
# 547   2024-01-23      20     99.78  137.1900          112.37
# 548   2024-01-23      21     95.43   65.1750           90.82
# 549   2024-01-23      22     82.13   92.9750           81.45
# 550   2024-01-23      23     73.50   97.7500           82.49
# 551   2024-01-23      24     50.13   97.7500           61.41
#
#      Weighted average price   Minimal price  Maximal price   Last price   \
# 0                       4.09           0.80            5.00         4.50
# 1                       6.11          -2.51           20.18         2.18
# 2                       7.00          -1.28           26.12         2.11
# 3                       2.13          -0.50            7.21         4.59
# 4                       2.89          -0.50            8.49         6.01
# ..                       ...            ...             ...          ...
# 547                   116.05          93.10          130.60       130.60
# 548                    98.89          81.51          125.85        84.00
# 549                    86.23          70.00          107.29        76.00
# 550                    85.01          73.50           95.48        73.50
# 551                    59.24          56.00           69.90        69.90
#
#      Profit_Loss
# 0        -5.1000
# 1        29.2400
# 2        -5.0500
# 3        -5.0100
# 4        -4.5075
# ..           ...
# 547      37.4100
# 548     -30.2550
# 549      10.8450
# 550      24.2500
# 551      47.6200
#
# [552 rows x 10 columns]

# %%
# Wybór danych tylko dla okresu 1 OKRES 1
df_period_1 = df[df['Period'] == 1]

df_period_1.head(5)  # Wyświetlenie wyników dla okresu 1
# Out:
#    Delivery day  Period  DA price   Bilans  Price Average   \
# 0    2024-01-01       1      0.10  -5.0000            3.14
# 24   2024-01-02       1     29.71  -5.0000           16.80
# 48   2024-01-03       1     21.93  30.7575           19.82
# 72   2024-01-04       1     57.30  29.2500           60.92
# 96   2024-01-05       1     86.08  97.5025           78.44
#
#     Weighted average price   Minimal price  Maximal price   Last price   \
# 0                      4.09           0.80            5.00         4.50
# 24                    19.51           4.11           40.95        30.00
# 48                    22.85           8.86           49.99        35.12
# 72                    65.05          52.81           78.45        78.45
# 96                    75.27          50.14          102.54        50.14
#
#     Profit_Loss
# 0       -5.1000
# 24     -34.7100
# 48       8.8275
# 72     -28.0500
# 96      11.4225

# %%
# Wybór danych tylko dla okresu 1
df_period_1 = df[df['Period'] == 1]

# Liczenie ile razy wystąpił zysk (Profit/Loss > 0) dla okresu 1
profit_count = df_period_1[df_period_1['Profit_Loss'] > 0].shape[0]

profit_count
# 7 razy zysk z longa dla okresu 1 na 23
# Out:
# 7

# %%
length = len(df_period_1)
length
# Out:
# 23

# %%
# Liczenie, ile razy 'Price Average' było większe od 'DA price' dla każdego okresu
count_higher_average_price = df[df['Price Average '] > df['DA price']].groupby('Period').size()

count_higher_average_price.head(24)  # Wyświetlenie wyników dla pierwszych kilku okresów

# TYLE RAZY DLA POSZCZEGULNYCH GODZIN CENA SREDNIA BYLA WYZSZA OD DA
# Out:
# Period
# 1      9
# 2     10
# 3     12
# 4     14
# 5     12
# 6     13
# 7     13
# 8     17
# 9     16
# 10    15
# 11    16
# 12    17
# 13    14
# 14    15
# 15    12
# 16    15
# 17     9
# 18    11
# 19    11
# 20    11
# 21    11
# 22    14
# 23     9
# 24    13
# dtype: int64

# %%
# Liczenie, ile razy 'Maximal price' było wyższe od 'DA price' o 5 dla każdego okresu
count_higher_maximal_price = df[df['Maximal price '] > df['DA price'] + 5].groupby('Period').size()

count_higher_maximal_price.head(24)  # Wyświetlenie wyników dla pierwszych kilku okresów

# TYLE RAZY MAXYMALAN CENA BYŁA WYZSZA OD DA O 5
# Out:
# Period
# 1     21
# 2     14
# 3     14
# 4     17
# 5     16
# 6     20
# 7     21
# 8     22
# 9     21
# 10    23
# 11    22
# 12    22
# 13    23
# 14    22
# 15    23
# 16    22
# 17    18
# 18    20
# 19    22
# 20    21
# 21    22
# 22    21
# 23    18
# 24    22
# dtype: int64

# %%
# Wybór wierszy, w których 'Profit_Loss' jest na plusie (większy od 0)
df_profit_positive = df[df['Profit_Loss'] > 0]

df_profit_positive.head(50)  # Wyświetlenie pierwszych kilku wierszy df_profit_positive
# Out:
#     Delivery day  Period  DA price     Bilans  Price Average   \
# 1     2024-01-01       2      0.01   29.25000            3.75
# 11    2024-01-01      12      0.54   29.25000            2.60
# 13    2024-01-01      14      3.44   63.50000            1.45
# 14    2024-01-01      15     11.18   97.75000            2.65
# 15    2024-01-01      16     43.85   97.75000           53.86
# 22    2024-01-01      23     44.59  130.74750           36.45
# 32    2024-01-02       9     80.12   99.09900           61.69
# 33    2024-01-02      10     78.46   86.30600           68.15
# 35    2024-01-02      12     79.66   87.62600           83.82
# 36    2024-01-02      13     81.93   90.12300           88.74
# 37    2024-01-02      14     83.02  130.50000           85.98
# 38    2024-01-02      15     85.98   94.57800           86.54
# 39    2024-01-02      16     87.67   96.43700           91.59
# 40    2024-01-02      17     90.19  107.40675           83.49
# 44    2024-01-02      21     60.22   64.87100           57.27
# 45    2024-01-02      22     48.02   58.16100           53.82
# 46    2024-01-02      23     40.93   54.26150           50.97
# 47    2024-01-02      24     25.28   37.45200           37.61
# 48    2024-01-03       1     21.93   30.75750           19.82
# 49    2024-01-03       2     20.69   28.24750           15.20
# 50    2024-01-03       3     19.77   29.25000           20.51
# 53    2024-01-03       6     22.82   29.25000           14.59
# 60    2024-01-03      13     57.39  125.25000           58.51
# 61    2024-01-03      14     57.08   91.00000           59.84
# 64    2024-01-03      17     80.59   91.00000           74.99
# 68    2024-01-03      21     73.23  127.50000           74.58
# 73    2024-01-04       2     50.46   62.75000           45.74
# 78    2024-01-04       7     72.65  132.00000           66.62
# 79    2024-01-04       8     85.02   96.12500           84.66
# 83    2024-01-04      12     90.76   97.75000           86.42
# 87    2024-01-04      16     98.62  102.92025           95.70
# 88    2024-01-04      17    104.74  109.34750           98.52
# 89    2024-01-04      18    115.23  119.53500          127.85
# 90    2024-01-04      19    118.06  162.82000          139.25
# 91    2024-01-04      20    112.32  113.00000          120.30
# 92    2024-01-04      21    101.41  141.97025          100.49
# 93    2024-01-04      22     95.75  132.52000           91.10
# 96    2024-01-05       1     86.08   97.50250           78.44
# 100   2024-01-05       5     73.18   96.00200           69.85
# 107   2024-01-05      12     98.58  101.40250           88.85
# 108   2024-01-05      13     97.94  136.33250           86.22
# 109   2024-01-05      14    104.58  143.00000           89.75
# 110   2024-01-05      15    112.34  155.63500           99.14
# 111   2024-01-05      16    113.91  159.47000          106.56
# 114   2024-01-05      19    113.27  153.25000          106.98
# 115   2024-01-05      20    110.70  151.00000          101.01
# 118   2024-01-05      23     94.92   95.50000           93.86
# 119   2024-01-05      24     86.80   96.25000           86.99
# 120   2024-01-06       1     82.25  131.25000           86.96
# 121   2024-01-06       2     80.20  131.25000           83.52
#
#      Weighted average price   Minimal price  Maximal price   Last price   \
# 1                       6.11          -2.51           20.18         2.18
# 11                      4.17          -3.10           14.00         1.00
# 13                      4.23          -5.20           13.41        12.22
# 14                      4.81          -5.00           28.50        17.23
# 15                     49.75          25.00           75.00        25.00
# 22                     36.30          20.29           53.43        20.75
# 32                     62.08          40.84           93.22        40.89
# 33                     65.41          41.02           92.33        41.77
# 35                     86.16          75.00          105.88        85.00
# 36                     90.54          76.63          112.28       112.08
# 37                     89.98          78.01          120.28        78.01
# 38                     89.25          74.24          113.45       113.15
# 39                     93.44          79.92          113.99       113.34
# 40                     90.38          75.16          120.22       120.03
# 44                     55.98          38.23           70.34        38.89
# 45                     54.68          44.00           64.29        64.19
# 46                     55.05          41.54           72.33        72.11
# 47                     42.71          20.69           67.88        67.88
# 48                     22.85           8.86           49.99        35.12
# 49                     14.55          10.00           25.00        11.42
# 50                     18.62          10.00           29.24        29.22
# 53                     12.77           4.50           25.00        13.20
# 60                     56.35          35.23           76.05        35.67
# 61                     59.96          35.11           81.34        55.00
# 64                     74.71          50.13           95.38        50.13
# 68                     71.84          48.27           83.40        48.27
# 73                     43.57          40.57           51.94        45.12
# 78                     66.96          62.85           73.74        69.80
# 79                     77.37          50.39           86.80        50.39
# 83                     86.57          50.27           95.00        50.88
# 87                     93.03          56.88          103.80        56.99
# 88                     96.40          54.49          107.21        54.88
# 89                    129.47         112.69          167.88       167.88
# 90                    140.38         123.25          174.89       174.89
# 91                    120.84         110.00          155.12       155.12
# 92                    104.86          88.45          140.19        88.45
# 93                     93.09          77.22          126.44       126.14
# 96                     75.27          50.14          102.54        50.14
# 100                    69.32          66.00           73.53        69.98
# 107                    88.47          60.23          111.39        60.24
# 108                    85.38          55.87          108.89        70.23
# 109                    86.62          60.34          109.78        89.00
# 110                   103.96          70.00          145.89        95.00
# 111                   110.54          96.00          150.11       150.11
# 114                   111.80          97.40          148.99       148.99
# 115                   103.49          90.00          125.34       125.34
# 118                    97.01          86.42          124.87       124.87
# 119                    90.34          80.81          115.34        90.00
# 120                    91.38          47.22          108.22       108.01
# 121                    83.11          80.23           89.54        89.54
#
#      Profit_Loss
# 1       29.24000
# 11      28.71000
# 13      60.06000
# 14      86.57000
# 15      53.90000
# 22      86.15750
# 32      18.97900
# 33       7.84600
# 35       7.96600
# 36       8.19300
# 37      47.48000
# 38       8.59800
# 39       8.76700
# 40      17.21675
# 44       4.65100
# 45      10.14100
# 46      13.33150
# 47      12.17200
# 48       8.82750
# 49       7.55750
# 50       9.48000
# 53       6.43000
# 60      67.86000
# 61      33.92000
# 64      10.41000
# 68      54.27000
# 73      12.29000
# 78      59.35000
# 79      11.10500
# 83       6.99000
# 87       4.30025
# 88       4.60750
# 89       4.30500
# 90      44.76000
# 91       0.68000
# 92      40.56025
# 93      36.77000
# 96      11.42250
# 100     22.82200
# 107      2.82250
# 108     38.39250
# 109     38.42000
# 110     43.29500
# 111     45.56000
# 114     39.98000
# 115     40.30000
# 118      0.58000
# 119      9.45000
# 120     49.00000
# 121     51.05000

# %%
# Liczenie ile razy 'Maximal price' było wyższe od 'Bilans'
count_maximal_price_higher_than_bilans = df_profit_positive[df_profit_positive['Maximal price '] > df_profit_positive['Bilans']].shape[0]

count_maximal_price_higher_than_bilans
# Out:
# 91

# %%
length1 = len(df_profit_positive)
length1
# Out:
# 236

# %%
df
# Out:
#     Delivery day  Period  DA price    Bilans  Price Average   \
# 0     2024-01-01       1      0.10   -5.0000            3.14
# 1     2024-01-01       2      0.01   29.2500            3.75
# 2     2024-01-01       3      0.05   -5.0000            4.21
# 3     2024-01-01       4      0.01   -5.0000            4.15
# 4     2024-01-01       5      0.01   -4.4975            3.73
# ..           ...     ...       ...       ...             ...
# 547   2024-01-23      20     99.78  137.1900          112.37
# 548   2024-01-23      21     95.43   65.1750           90.82
# 549   2024-01-23      22     82.13   92.9750           81.45
# 550   2024-01-23      23     73.50   97.7500           82.49
# 551   2024-01-23      24     50.13   97.7500           61.41
#
#      Weighted average price   Minimal price  Maximal price   Last price   \
# 0                       4.09           0.80            5.00         4.50
# 1                       6.11          -2.51           20.18         2.18
# 2                       7.00          -1.28           26.12         2.11
# 3                       2.13          -0.50            7.21         4.59
# 4                       2.89          -0.50            8.49         6.01
# ..                       ...            ...             ...          ...
# 547                   116.05          93.10          130.60       130.60
# 548                    98.89          81.51          125.85        84.00
# 549                    86.23          70.00          107.29        76.00
# 550                    85.01          73.50           95.48        73.50
# 551                    59.24          56.00           69.90        69.90
#
#      Profit_Loss  Difference_max
# 0        -5.1000            4.90
# 1        29.2400           20.17
# 2        -5.0500           26.07
# 3        -5.0100            7.20
# 4        -4.5075            8.48
# ..           ...             ...
# 547      37.4100           30.82
# 548     -30.2550           30.42
# 549      10.8450           25.16
# 550      24.2500           21.98
# 551      47.6200           19.77
#
# [552 rows x 11 columns]

# %%
df.columns
# Out:
# Index(['Delivery day', 'Period', 'DA price', 'Bilans', 'Price Average ',
#        'Weighted average price ', 'Minimal price', 'Maximal price ',
#        'Last price ', 'Profit_Loss', 'Difference_max'],
#       dtype='object')

# %%
# Obliczanie różnic między 'DA price' i 'Maximal price'
df['Difference_max'] = df['Maximal price '] - df['DA price']

# Sortowanie danych według największych różnic i wybranie 10 pierwszych
top_10_differences = df.sort_values(by='Difference_max', ascending=False).head(15)

top_10_differences  # Wyświetlenie wyników

## 10 NAJWIKESZYCH RÓŻNIC MIEZDZY MAX A CENA DA
# Out:
#     Delivery day  Period  DA price     Bilans  Price Average   \
# 189   2024-01-08      22    102.80  112.85500          139.42
# 513   2024-01-22      10    101.04  102.59000          124.40
# 233   2024-01-10      18    143.79  143.07500          178.54
# 235   2024-01-10      20    132.15  137.50500          169.80
# 226   2024-01-10      11    119.49   -0.90000          150.73
# 200   2024-01-09       9    132.94  136.27750          162.17
# 180   2024-01-08      13     95.48  145.20000          130.49
# 546   2024-01-23      19     90.00   97.50000          136.01
# 234   2024-01-10      19    140.00   95.49750          170.10
# 187   2024-01-08      20    122.05  170.86750          155.41
# 185   2024-01-08      18    130.83  175.50000          162.55
# 393   2024-01-17      10    105.50  109.62500          126.14
# 446   2024-01-19      15     76.09   32.18225           94.99
# 188   2024-01-08      21    114.19  162.71500          149.83
# 202   2024-01-09      11    112.46   37.73500          118.41
#
#      Weighted average price   Minimal price  Maximal price   Last price   \
# 189                   136.05         100.00          230.70       105.33
# 513                   127.51          90.94          210.00        95.12
# 233                   179.46         116.11          230.00       116.11
# 235                   173.52         130.00          217.08       130.00
# 226                   150.76          96.37          200.00       150.00
# 200                   155.57         120.29          207.70       120.29
# 180                   132.48          95.00          169.99       150.00
# 546                   135.98         100.12          162.00       125.87
# 234                   172.06         112.84          211.65       140.00
# 187                   158.30         127.81          191.34       150.00
# 185                   162.07         126.69          200.00       200.00
# 393                   128.60          84.40          174.57       162.47
# 446                    93.94          76.09          145.10       145.10
# 188                   149.09         129.98          181.79       181.79
# 202                   121.37         108.49          180.00       180.00
#
#      Profit_Loss  Difference_max
# 189     10.05500          127.90
# 513      1.55000          108.96
# 233     -0.71500           86.21
# 235      5.35500           84.93
# 226   -120.39000           80.51
# 200      3.33750           74.76
# 180     49.72000           74.51
# 546      7.50000           72.00
# 234    -44.50250           71.65
# 187     48.81750           69.29
# 185     44.67000           69.17
# 393      4.12500           69.07
# 446    -43.90775           69.01
# 188     48.52500           67.60
# 202    -74.72500           67.54
