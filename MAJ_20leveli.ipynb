# %% [markdown]
# <a href="https://colab.research.google.com/github/tomektom10/dataScienceBootCamp/blob/main/MAJ_20leveli.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import pandas as pd
import numpy as np

# %%
df = pd.read_excel("MAJ_do_liczenia.xlsx")

# %%
df.columns
# Out:
# Index(['Delivery day', 'Period number', 'Period',
#        'Traded Price Average (EUR/MWh)',
#        'Weighted average price of all trades (EUR/MWh)',
#        'Minimal price (EUR/MWh)', 'Maximal price (EUR/MWh)',
#        'Last price (EUR/MWh)', 'Price SK (EUR/MWh)', 'Bilans'],
#       dtype='object')

# %%
df['Profit/Loss'] = df['Bilans'] - df['Price SK (EUR/MWh)']

# %%
total_profit_loss = df['Profit/Loss'].sum()
total_profit_loss
# Out:
# -4184.350999999999

# %%
# Konwersja kolumny 'Delivery day' na typ daty
df['Delivery day'] = pd.to_datetime(df['Delivery day'])

# Dodanie kolumny identyfikującej dzień tygodnia (0=Poniedziałek, 6=Niedziela)
df['Day of Week'] = df['Delivery day'].dt.dayofweek

# Filtracja dni tygodnia (0-4 to Poniedziałek-Piątek)
weekday_df = df[df['Day of Week'] < 5]

# Filtracja weekendów (5-6 to Sobota-Niedziela)
weekend_df = df[df['Day of Week'] >= 5]

# Usunięcie pomocniczej kolumny 'Day of Week' jeśli nie jest już potrzebna
weekday_df = weekday_df.drop(columns=['Day of Week'])
weekend_df = weekend_df.drop(columns=['Day of Week'])

# %%
weekday_df
# Out:
#     Delivery day  Period number         Period  \
# 0     2024-05-01              1  00:00 - 01:00
# 1     2024-05-01              2  01:00 - 02:00
# 2     2024-05-01              3  02:00 - 03:00
# 3     2024-05-01              4  03:00 - 04:00
# 4     2024-05-01              5  04:00 - 05:00
# ..           ...            ...            ...
# 691   2024-05-29             20  19:00 - 20:00
# 692   2024-05-29             21  20:00 - 21:00
# 693   2024-05-29             22  21:00 - 22:00
# 694   2024-05-29             23  22:00 - 23:00
# 695   2024-05-29             24  23:00 - 00:00
#
#      Traded Price Average (EUR/MWh)  \
# 0                             44.07
# 1                             38.97
# 2                             27.43
# 3                             41.05
# 4                             37.03
# ..                              ...
# 691                          135.08
# 692                          161.78
# 693                          154.12
# 694                          129.35
# 695                          104.78
#
#      Weighted average price of all trades (EUR/MWh)  Minimal price (EUR/MWh)  \
# 0                                             44.21                    27.20
# 1                                             37.14                    36.00
# 2                                             28.22                    18.57
# 3                                             36.27                    28.49
# 4                                             37.23                    29.99
# ..                                              ...                      ...
# 691                                          127.54                    85.17
# 692                                          176.22                   141.02
# 693                                          149.77                   108.11
# 694                                          141.50                   117.00
# 695                                          111.45                    94.38
#
#      Maximal price (EUR/MWh)  Last price (EUR/MWh)  Price SK (EUR/MWh)  \
# 0                      50.60                 27.20               65.81
# 1                      40.21                 36.00               55.49
# 2                      44.75                 44.75               50.51
# 3                      53.90                 53.90               44.65
# 4                      43.08                 43.01               47.52
# ..                       ...                   ...                 ...
# 691                   155.09                 85.17              138.39
# 692                   231.76                231.76              162.74
# 693                   232.00                108.11              157.77
# 694                   170.23                170.23              118.69
# 695                   140.39                140.39              101.17
#
#        Bilans  Profit/Loss
# 0    132.0000      66.1900
# 1    130.2500      74.7600
# 2    126.7500      76.2400
# 3    126.7500      82.1000
# 4    128.5000      80.9800
# ..        ...          ...
# 691  188.3700      49.9800
# 692  219.4575      56.7175
# 693   54.4675    -103.3025
# 694   39.2525     -79.4375
# 695   69.3150     -31.8550
#
# [504 rows x 11 columns]

# %%
# Obliczenie różnicy między 'Maximal price' a 'Price SK'
weekday_df['Price Difference'] = weekday_df['Maximal price (EUR/MWh)'] - weekday_df['Price SK (EUR/MWh)']

# Filtracja rekordów, gdzie różnica była większa lub równa 20
filtered_df = weekday_df[weekday_df['Price Difference'] >= 20]

# Grupowanie danych po kolumnie 'Period number' i zliczanie rekordów w każdej grupie
dni_tygodnia_pogrupowane = filtered_df.groupby('Period number').size().reset_index(name='Count')

# %%
dni_tygodnia_pogrupowane
# Out:
#     Period number  Count
# 0               1     16
# 1               2     11
# 2               3     11
# 3               4     11
# 4               5     12
# 5               6     12
# 6               7     12
# 7               8     16
# 8               9     13
# 9              10     15
# 10             11     13
# 11             12     11
# 12             13     11
# 13             14     15
# 14             15     15
# 15             16     14
# 16             17     14
# 17             18     17
# 18             19     15
# 19             20     17
# 20             21     18
# 21             22     19
# 22             23     16
# 23             24     14

# %%
period_1_count = (weekday_df['Period number'] == 1).sum()

# %%
period_1_count
# Out:
# 21

# %%
# Obliczenie różnicy między 'Price SK' a 'Minimal price'
weekday_df['Price Difference'] = weekday_df['Price SK (EUR/MWh)'] - weekday_df['Minimal price (EUR/MWh)']

# Filtracja rekordów, gdzie różnica była większa lub równa 20
filtered_df_szort = weekday_df[weekday_df['Price Difference'] >= 20]

# Grupowanie danych po kolumnie 'Period' i zliczanie rekordów w każdej grupie
pogrupowane_szort = filtered_df_szort.groupby('Period').size().reset_index(name='Count')

# %%
pogrupowane_szort
# Out:
#            Period  Count
# 0   00:00 - 01:00      7
# 1   01:00 - 02:00      7
# 2   02:00 - 03:00      9
# 3   03:00 - 04:00      6
# 4   04:00 - 05:00      6
# 5   05:00 - 06:00      5
# 6   06:00 - 07:00     12
# 7   07:00 - 08:00     16
# 8   08:00 - 09:00     12
# 9   09:00 - 10:00     13
# 10  10:00 - 11:00      8
# 11  11:00 - 12:00     10
# 12  12:00 - 13:00     10
# 13  13:00 - 14:00     10
# 14  14:00 - 15:00      8
# 15  15:00 - 16:00     10
# 16  16:00 - 17:00     12
# 17  17:00 - 18:00     12
# 18  18:00 - 19:00      8
# 19  19:00 - 20:00     14
# 20  20:00 - 21:00     16
# 21  21:00 - 22:00      8
# 22  22:00 - 23:00      9
# 23  23:00 - 00:00     12

# %%
# Obliczenie różnicy między 'Maximal price' a 'Price SK'
weekend_df['Price Difference'] = weekend_df['Maximal price (EUR/MWh)'] - weekend_df['Price SK (EUR/MWh)']

# Filtracja rekordów, gdzie różnica była większa lub równa 20
filtered_df_weekend = weekend_df[weekend_df['Price Difference'] >= 20]

# Grupowanie danych po kolumnie 'Period number' i zliczanie rekordów w każdej grupie
weekend_pogrupowane = filtered_df_weekend.groupby('Period number').size().reset_index(name='Count')

# %%
weekend_pogrupowane
# Out:
#     Period number  Count
# 0               1      5
# 1               2      5
# 2               3      4
# 3               4      3
# 4               5      3
# 5               6      5
# 6               7      4
# 7               8      3
# 8               9      3
# 9              10      3
# 10             11      4
# 11             12      5
# 12             13      5
# 13             14      5
# 14             15      6
# 15             16      4
# 16             17      5
# 17             18      5
# 18             19      6
# 19             20      5
# 20             21      6
# 21             22      6
# 22             23      4
# 23             24      4

# %%
# Obliczenie różnicy między 'Price SK' a 'Minimal price'
weekend_df['Price Difference'] = weekend_df['Price SK (EUR/MWh)'] - weekend_df['Minimal price (EUR/MWh)']

# Filtracja rekordów, gdzie różnica była większa lub równa 20
weekend_df_szort = weekend_df[weekend_df['Price Difference'] >= 20]

# Grupowanie danych po kolumnie 'Period' i zliczanie rekordów w każdej grupie
pogrupowane_weekend_szort = weekend_df_szort.groupby('Period').size().reset_index(name='Count')

# %%
pogrupowane_weekend_szort
# Out:
#            Period  Count
# 0   00:00 - 01:00      6
# 1   01:00 - 02:00      4
# 2   02:00 - 03:00      4
# 3   03:00 - 04:00      3
# 4   04:00 - 05:00      3
# 5   05:00 - 06:00      3
# 6   06:00 - 07:00      4
# 7   07:00 - 08:00      2
# 8   08:00 - 09:00      5
# 9   09:00 - 10:00      3
# 10  10:00 - 11:00      5
# 11  11:00 - 12:00      4
# 12  12:00 - 13:00      4
# 13  13:00 - 14:00      1
# 14  14:00 - 15:00      2
# 15  15:00 - 16:00      2
# 16  16:00 - 17:00      3
# 17  17:00 - 18:00      2
# 18  18:00 - 19:00      6
# 19  19:00 - 20:00      6
# 20  20:00 - 21:00      4
# 21  21:00 - 22:00      4
# 22  22:00 - 23:00      6
# 23  23:00 - 00:00      4

# %%
period_1_count_weekend = (weekend_df['Period number'] == 1).sum()

# %%
period_1_count_weekend
# Out:
# 8

# %%
#333###### wyviaganie perwszego wiersza gdzie nie dało sie zamknac po 20 levelach

# %%
# Filtracja wierszy, gdzie Maximal price nie jest o 20 większa od Price SK i Period number jest od 14 do 21
nie_dali20 = weekday_df[(weekday_df['Maximal price (EUR/MWh)'] <= weekday_df['Price SK (EUR/MWh)'] + 20) & (weekday_df['Period number'] >= 14) & (weekday_df['Period number'] <= 21)]

# Wyciągnięcie pierwszego wiersza spełniającego warunek
first_row = nie_dali20.iloc[0] if not filtered_df.empty else None

# %%
first_row
# Out:
# Delivery day                                      2024-05-02 00:00:00
# Period number                                                      19
# Period                                                  18:00 - 19:00
# Traded Price Average (EUR/MWh)                                  96.74
# Weighted average price of all trades (EUR/MWh)                  96.23
# Minimal price (EUR/MWh)                                         82.68
# Maximal price (EUR/MWh)                                         115.0
# Last price (EUR/MWh)                                             90.0
# Price SK (EUR/MWh)                                               97.5
# Bilans                                                          98.75
# Profit/Loss                                                      1.25
# Price Difference                                                14.82
# Name: 42, dtype: object

# %%
# Filtracja wierszy, gdzie Maximal price nie jest o 20 większa od Price SK i Period number jest od 14 do 21
filtered_df = weekday_df[(weekday_df['Maximal price (EUR/MWh)'] <= weekday_df['Price SK (EUR/MWh)'] + 20) & (weekday_df['Period number'] >= 14) & (weekday_df['Period number'] <= 21)]

# %%
filtered_df
# Out:
#     Delivery day  Period number         Period  \
# 42    2024-05-02             19  18:00 - 19:00
# 43    2024-05-02             20  19:00 - 20:00
# 64    2024-05-03             17  16:00 - 17:00
# 68   165.9525      38.9425             77.01
# 133   -4.7250     -56.0650             61.34
# 134   -3.9750     -53.0350             48.06
# 135   -4.7250     -63.6750             44.94
# 136  129.5000      49.2500             50.25
# 137  130.7500      41.6300             37.71
# 162  103.3400      -0.0600             13.40
# 183  130.7500      60.5500             40.20
# 185  132.0000      47.0800             54.92
# 206   -6.9425      -1.9825             10.27
# 209   64.0025       0.0325             62.85
# 229   -4.5365      -1.6765             38.74
# 230   27.7500      30.8400             16.91
# 231   -5.0000     -22.8000             26.26
# 232   96.2500      33.1000             43.04
# 373   -5.0000     -22.6500            117.65
# 374   -3.4250     -29.5250            196.09
# 375   -2.5250     -58.1650             20.10
# 376   30.4250     -26.3450             36.63
# 495   63.5000      -9.0200             -6.23
# 496   29.9000     -53.0800             20.00
# 517   -5.0000     -60.3200             35.87
# 519  128.2500      53.3900             44.68
# 520   -2.8000     -92.2300             32.44
# 521   28.6500     -66.6200             22.89
# 522   31.4500     -69.4300             50.49
# 523   44.8000     -96.9500             56.52
# 524  155.1725       0.5925             67.66
# 565   94.7500      20.3500             29.24
# 567   28.0000     -53.6800             35.86
# 568   -3.0000     -87.3400             44.18
# 569   32.0000     -67.1700             48.78
# 570   76.0500     -36.2400             49.01
# 572   -0.7000    -139.2400             60.40
# 637   -3.0500     -70.1600              9.07
# 638   -4.4975     -70.7675             38.27
# 685   61.6500      -1.6800             21.33
# 686   61.6500      -1.6500             23.30
# 690  112.8300       1.6400             49.32
# 691  188.3700      49.9800             53.22

# %%
total_profit_loss_niedali20 = filtered_df['Profit/Loss'].sum()
total_profit_loss_niedali20
# Out:
# -1058.1840000000002

# %%
number_of_rows = len(filtered_df)

# %%
number_of_rows
# Out:
# 46

# %%
strata_1 = filtered_df[filtered_df["Last price (EUR/MWh)"] < filtered_df["Price SK (EUR/MWh)"] - 1]

# %%
strata_1
# Out:
#     Delivery day  Period number         Period  \
# 42    2024-05-02             19  18:00 - 19:00
# 43    2024-05-02             20  19:00 - 20:00
# 64    2024-05-03             17  16:00 - 17:00
# 67    2024-05-03             20  19:00 - 20:00
# 68    2024-05-03             21  20:00 - 21:00
# 133   2024-05-06             14  13:00 - 14:00
# 134   2024-05-06             15  14:00 - 15:00
# 135   2024-05-06             16  15:00 - 16:00
# 136   2024-05-06             17  16:00 - 17:00
# 162   2024-05-07             19  18:00 - 19:00
# 183   2024-05-08             16  15:00 - 16:00
# 185   2024-05-08             18  17:00 - 18:00
# 206   2024-05-09             15  14:00 - 15:00
# 209   2024-05-09             18  17:00 - 18:00
# 229   2024-05-10             14  13:00 - 14:00
# 231   2024-05-10             16  15:00 - 16:00
# 232   2024-05-10             17  16:00 - 17:00
# 373   2024-05-16             14  13:00 - 14:00
# 374   2024-05-16             15  14:00 - 15:00
# 375   2024-05-16             16  15:00 - 16:00
# 376   2024-05-16             17  16:00 - 17:00
# 496   2024-05-21             17  16:00 - 17:00
# 517   2024-05-22             14  13:00 - 14:00
# 519   2024-05-22             16  15:00 - 16:00
# 520   2024-05-22             17  16:00 - 17:00
# 522   2024-05-22             19  18:00 - 19:00
# 523   2024-05-22             20  19:00 - 20:00
# 376                    63.99                 33.00               56.77
# 496                    95.00                 62.98               82.98
# 517                    66.00                 19.45               55.32
# 519                    83.00                 62.05               74.86
# 520                   104.50                 85.00               89.43
# 522                   105.00                 50.39              100.88
# 523                   148.00                120.00              141.75
# 524                   163.00                 86.92              154.58
# 567                    92.39                 45.82               81.68
# 568                    85.32                 40.16               84.34
# 569                   106.50                 50.39               99.17
# 570                   115.50                 63.28              112.29
# 572                   156.00                 78.14              138.54
# 638                    68.10                 30.06               66.27
# 685                    65.34                 56.02               63.33
# 690                   128.00                 61.87              111.19
# 691                   155.09                 85.17              138.39
#
#        Bilans  Profit/Loss  Price Difference
# 42    98.7500       1.2500             14.82
# 43   145.8500      41.6700             43.79
# 64    -4.7250     -74.8550             31.58
# 67   142.7500      34.3900             24.36
# 68   165.9525      38.9425             77.01
# 133   -4.7250     -56.0650             61.34
# 134   -3.9750     -53.0350             48.06
# 135   -4.7250     -63.6750             44.94
# 136  129.5000      49.2500             50.25
# 162  103.3400      -0.0600             13.40
# 183  130.7500      60.5500             40.20
# 185  132.0000      47.0800             54.92
# 206   -6.9425      -1.9825             10.27
# 209   64.0025       0.0325             62.85
# 229   -4.5365      -1.6765             38.74
# 231   -5.0000     -22.8000             26.26
# 232   96.2500      33.1000             43.04
# 373   -5.0000     -22.6500            117.65
# 374   -3.4250     -29.5250            196.09
# 375   -2.5250     -58.1650             20.10
# 376   30.4250     -26.3450             36.63
# 496   29.9000     -53.0800             20.00
# 517   -5.0000     -60.3200             35.87
# 519  128.2500      53.3900             44.68
# 520   -2.8000     -92.2300             32.44
# 522   31.4500     -69.4300             50.49
# 523   44.8000     -96.9500             56.52
# 524  155.1725       0.5925             67.66
# 567   28.0000     -53.6800             35.86
# 568   -3.0000     -87.3400             44.18
# 569   32.0000     -67.1700             48.78
# 570   76.0500     -36.2400             49.01
# 572   -0.7000    -139.2400             60.40
# 638   -4.4975     -70.7675             38.27
# 685   61.6500      -1.6800             21.33
# 690  112.8300       1.6400             49.32
# 691  188.3700      49.9800             53.22

# %%
number_of_rows1 = len(strata_1)
number_of_rows1
# Out:
# 37

# %%
tylko_wdol= weekday_df[(weekday_df["Maximal price (EUR/MWh)"] < weekday_df["Price SK (EUR/MWh)"]) & (weekday_df["Period number"].between(14, 21))]

# Wyświetlanie nowego DataFrame
tylko_wdol
# Out:
#     Delivery day  Period number         Period  \
# 133   2024-05-06             14  13:00 - 14:00
# 134   2024-05-06             15  14:00 - 15:00
# 135   2024-05-06             16  15:00 - 16:00
#
#      Traded Price Average (EUR/MWh)  \
# 133                           25.55
# 134                           21.56
# 135                           35.83
#
#      Weighted average price of all trades (EUR/MWh)  Minimal price (EUR/MWh)  \
# 133                                           25.16                   -10.00
# 134                                           22.00                     1.00
# 135                                           32.73                    14.01
#
#      Maximal price (EUR/MWh)  Last price (EUR/MWh)  Price SK (EUR/MWh)  \
# 133                    48.33                  9.23               51.34
# 134                    42.00                 25.00               49.06
# 135                    49.55                 20.04               58.95
#
#      Bilans  Profit/Loss  Price Difference
# 133  -4.725      -56.065             61.34
# 134  -3.975      -53.035             48.06
# 135  -4.725      -63.675             44.94
