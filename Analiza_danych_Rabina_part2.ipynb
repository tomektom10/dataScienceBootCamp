# %% [markdown]
# <a href="https://colab.research.google.com/github/tomektom10/dataScienceBootCamp/blob/main/Analiza_danych_Rabina_part2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import pandas as pd
import numpy as np

# %%
df = pd.read_excel("Anal_SK.xlsx", sheet_name="P_1")

# %%
df
# Out:
#                                      Time  Day-ahead price  Imbalance price  \
# 0     01.01.2023 00:00 - 01.01.2023 01:00            20.26          -5.0000
# 1     01.01.2023 01:00 - 01.01.2023 02:00             0.33          -2.2500
# 2     01.01.2023 02:00 - 01.01.2023 03:00             0.50          -5.0000
# 3     01.01.2023 03:00 - 01.01.2023 04:00             0.50          -5.0000
# 4     01.01.2023 04:00 - 01.01.2023 05:00             0.10          -5.0000
# ...                                   ...              ...              ...
# 7458                                  NaN              NaN          -5.0000
# 7459                                  NaN              NaN         125.4925
# 7460                                  NaN              NaN         161.0000
# 7461                                  NaN              NaN         150.2100
# 7462                                  NaN              NaN          63.5150
#
# ...

# %%
wybrane_kolumny = df[['LONG/SHORT', 'Profit/loss']]

# %%
wybrane_kolumny
# Out:
#      LONG/SHORT  Profit/loss
# 0         SHORT      25.2600
# 1         SHORT       2.5800
# 2         SHORT       5.5000
# 3         SHORT       5.5000
# 4         SHORT       5.1000
# ...         ...          ...
# 7458      SHORT     128.1000
# 7459      SHORT     -12.8325
# 7460      SHORT     -53.6700
# 7461      SHORT     -50.0700
# 7462      SHORT      24.5050
#
# [7463 rows x 2 columns]

# %%
suma_wartosci_Profit = df['Profit/loss'].sum()

# %%
df.groupby("LONG/SHORT")["Profit/loss"].mean()
# Out:
# LONG/SHORT
# LONG     -6.307024
# SHORT    16.933258
# Name: Profit/loss, dtype: float64

# %%
long_data = wybrane_kolumny[wybrane_kolumny['LONG/SHORT'] == 'LONG']

# %%
print(long_data)
# Out:
#      LONG/SHORT  Profit/loss
# 9          LONG      -6.1900
# 10         LONG      -6.9100
# 11         LONG      -7.7400
# 12         LONG      -7.7900
# 13         LONG      -7.7575
# ...         ...          ...
# 7428       LONG      44.2000
# 7437       LONG     -24.5950
# 7438       LONG      10.4000
# 7449       LONG     -24.1300
# 7450       LONG     -57.7050
#
# [4006 rows x 2 columns]

# %%
suma_wartosci_long =long_data["Profit/loss"].sum()

# %%
# GRANIE TYLKO LONG

# %%
print(suma_wartosci_long)
# Out:
# -25265.94

# %%
szort_data = wybrane_kolumny[wybrane_kolumny['LONG/SHORT'] == 'SHORT']

# %%
print(szort_data)
# Out:
#      LONG/SHORT  Profit/loss
# 0         SHORT      25.2600
# 1         SHORT       2.5800
# 2         SHORT       5.5000
# 3         SHORT       5.5000
# 4         SHORT       5.1000
# ...         ...          ...
# 7458      SHORT     128.1000
# 7459      SHORT     -12.8325
# 7460      SHORT     -53.6700
# 7461      SHORT     -50.0700
# 7462      SHORT      24.5050
#
# [3457 rows x 2 columns]

# %%
suma_wartosci_szort =szort_data["Profit/loss"].sum()

# %%
#GRANIE TYLKO SZORT

# %%
print(suma_wartosci_szort)
# Out:
# 58538.27250000001

# %%
df
# Out:
#                                      Time  Day-ahead price  Imbalance price  \
# 0     01.01.2023 00:00 - 01.01.2023 01:00            20.26          -5.0000
# 1     01.01.2023 01:00 - 01.01.2023 02:00             0.33          -2.2500
# 2     01.01.2023 02:00 - 01.01.2023 03:00             0.50          -5.0000
# 3     01.01.2023 03:00 - 01.01.2023 04:00             0.50          -5.0000
# 4     01.01.2023 04:00 - 01.01.2023 05:00             0.10          -5.0000
# ...                                   ...              ...              ...
# 7458                                  NaN              NaN          -5.0000
# 7459                                  NaN              NaN         125.4925
# 7460                                  NaN              NaN         161.0000
# 7461                                  NaN              NaN         150.2100
# 7462                                  NaN              NaN          63.5150
#
# ...
