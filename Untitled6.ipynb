# %% [markdown]
# <a href="https://colab.research.google.com/github/tomektom10/dataScienceBootCamp/blob/main/Untitled6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import pandas as pd
import numpy as np

# %%
df = pd.read_excel("kkkkkkkk.xlsx")

# %%
df.drop('Unnamed: 10', axis=1, inplace=True)
df.drop('Unnamed: 11', axis=1, inplace=True)
df['Profit_Loss'] = df['Bilans'] - df['Price SK (EUR/MWh)']

# %%
df.columns
# Out:
# Index(['Delivery day', 'Period number', 'Period',
#        'Traded Price Average (EUR/MWh)',
#        'Weighted average price of all trades (EUR/MWh)',
#        'Minimal price (EUR/MWh)', 'Maximal price (EUR/MWh)',
#        'Last price (EUR/MWh)', 'Bilans', 'Price SK (EUR/MWh)', 'Profit_Loss'],
#       dtype='object')

# %%
df
# Out:
#      Delivery day  Period number         Period  \
# 0      2023-01-01            1.0  00:00 - 01:00
# 1      2023-01-01            2.0  01:00 - 02:00
# 2      2023-01-01            3.0  02:00 - 03:00
# 3      2023-01-01            4.0  03:00 - 04:00
# 4      2023-01-01            5.0  04:00 - 05:00
# ...           ...            ...            ...
# 8756   2023-12-31           21.0  20:00 - 21:00
# 8757   2023-12-31           22.0  21:00 - 22:00
# 8758   2023-12-31           23.0  22:00 - 23:00
# 8759   2023-12-31           24.0  23:00 - 00:00
# 8760          NaT            NaN            NaN
#
#       Traded Price Average (EUR/MWh)  \
# 0                              19.40
# 1                               3.07
# 2                               4.18
# 3                               4.40
# 4                               5.08
# ...                              ...
# 8756                           26.51
# 8757                           17.22
# 8758                           16.81
# ...

# %%
# Extract the top 30 rows with the highest 'Profit_Loss' values
top_30_profits = df.nlargest(30, 'Profit_Loss')

top_30_profits[['Delivery day', 'Period number', 'Price SK (EUR/MWh)', "Bilans" ,'Profit_Loss']]
# Out:
#      Delivery day  Period number  Price SK (EUR/MWh)    Bilans  Profit_Loss
# 6091   2023-09-11           20.0              444.02  666.0300     222.0100
# 6092   2023-09-11           21.0              394.00  591.0000     197.0000
# 711    2023-01-30           16.0              297.93  446.8950     148.9650
# 709    2023-01-30           14.0              285.94  428.9100     142.9700
# 705    2023-01-30           10.0              284.62  426.9300     142.3100
# 714    2023-01-30           19.0              277.81  416.7150     138.9050
# 92     2023-01-04           21.0              276.56  414.8400     138.2800
# 703    2023-01-30            8.0              276.40  414.6000     138.2000
# 88     2023-01-04           17.0              275.34  413.0100     137.6700
# 6115   2023-09-12           20.0              271.13  406.6950     135.5650
# 706    2023-01-30           11.0              268.16  402.2400     134.0800
# ...
